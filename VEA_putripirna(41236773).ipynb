# %% [markdown]
# <a href="https://colab.research.google.com/github/putripirna75-bot/natural-style-transfer/blob/main/VEA_putripirna(41236773).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -------------------------------
# Tugas 1: Bangun VAE untuk Fashion-MNIST
# -------------------------------

import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, losses, optimizers
import matplotlib.pyplot as plt

# -------------------------------
# 1. Load dan Preproses Data
# -------------------------------
(x_train, _), (x_test, _) = keras.datasets.fashion_mnist.load_data()

# Konversi ke float32 dan normalisasi ke [0, 1]
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# Tambahkan padding menjadi 32x32
x_train = np.pad(x_train, ((0, 0), (2, 2), (2, 2)), constant_values=0.0)
x_test = np.pad(x_test, ((0, 0), (2, 2), (2, 2)), constant_values=0.0)

# Tambahkan channel grayscale (32, 32, 1)
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)

print("Data shape:", x_train.shape, x_test.shape)
# Out:
# Data shape: (60000, 32, 32, 1) (10000, 32, 32, 1)

# %%
# -------------------------------
# 2. Bangun Encoder
# -------------------------------
latent_dim = 2

encoder_input = layers.Input(shape=(32, 32, 1), name="encoder_input")
x = layers.Conv2D(32, (3, 3), strides=2, padding="same", activation="relu")(encoder_input)
x = layers.Conv2D(64, (3, 3), strides=2, padding="same", activation="relu")(x)
x = layers.Conv2D(128, (3, 3), strides=2, padding="same", activation="relu")(x)
shape_before_flattening = x.shape[1:]  # simpan shape untuk decoder
x = layers.Flatten()(x)
z_mean = layers.Dense(latent_dim, name="z_mean")(x)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)

# Sampling layer dengan reparameterization trick
class Sampling(layers.Layer):
    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.random.normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

z = Sampling()([z_mean, z_log_var])
encoder = models.Model(encoder_input, [z_mean, z_log_var, z], name="encoder")
encoder.summary()
# Out:
# Model: "encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ encoder_input       │ (None, 32, 32, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 16, 16,    │        320 │ encoder_input[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 8, 8, 64)  │     18,496 │ conv2d_4[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 4, 4, 128) │     73,856 │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_1 (Flatten) │ (None, 2048)      │          0 │ conv2d_6[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_mean (Dense)      │ (None, 2)         │      4,098 │ flatten_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_log_var (Dense)   │ (None, 2)         │      4,098 │ flatten_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sampling_1          │ (None, 2)         │          0 │ z_mean[0][0],     │
# │ (Sampling)          │                   │            │ z_log_var[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 100,868 (394.02 KB)
#  Trainable params: 100,868 (394.02 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# -------------------------------
# 3. Bangun Decoder
# -------------------------------
decoder_input = layers.Input(shape=(latent_dim,), name="decoder_input")
x = layers.Dense(np.prod(shape_before_flattening), activation="relu")(decoder_input)
x = layers.Reshape(shape_before_flattening)(x)
x = layers.Conv2DTranspose(128, (3, 3), strides=2, padding="same", activation="relu")(x)
x = layers.Conv2DTranspose(64, (3, 3), strides=2, padding="same", activation="relu")(x)
x = layers.Conv2DTranspose(32, (3, 3), strides=2, padding="same", activation="relu")(x)
decoder_output = layers.Conv2D(1, (3, 3), padding="same", activation="sigmoid")(x)
decoder = models.Model(decoder_input, decoder_output, name="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ decoder_input (InputLayer)      │ (None, 2)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2048)           │         6,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_1 (Reshape)             │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_3              │ (None, 8, 8, 128)      │       147,584 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_4              │ (None, 16, 16, 64)     │        73,792 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_5              │ (None, 32, 32, 32)     │        18,464 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 32, 32, 1)      │           289 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 246,273 (962.00 KB)
#  Trainable params: 246,273 (962.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# -------------------------------
# 4. Bangun VAE dengan Custom Training Loop
# -------------------------------
class VAE(models.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(name="reconstruction_loss")
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [self.total_loss_tracker, self.reconstruction_loss_tracker, self.kl_loss_tracker]

    def call(self, inputs):
        z_mean, z_log_var, z = self.encoder(inputs)
        reconstruction = self.decoder(z)
        return z_mean, z_log_var, reconstruction

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, reconstruction = self(data)
            # Reconstruction loss
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum(
                    losses.binary_crossentropy(data, reconstruction),
                    axis=(1, 2)
                )
            )
            # KL divergence loss
            kl_loss = -0.5 * tf.reduce_mean(
                tf.reduce_sum(1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var), axis=1)
            )
            total_loss = reconstruction_loss + kl_loss

        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))

        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)

        return {m.name: m.result() for m in self.metrics}

# Instansiasi dan kompilasi VAE
vae = VAE(encoder, decoder)
vae.compile(optimizer=optimizers.Adam())

# %%
# -------------------------------
# 5. Latih Model
# -------------------------------
# Re-compile VAE with a dummy loss as the original compile was missing it
# Correcting the loss argument to match the multiple outputs of VAE.call() for validation.
vae.compile(optimizer=optimizers.Adam(), loss=[None, None, tf.keras.losses.MeanSquaredError()])
history = vae.fit(x_train, epochs=30, batch_size=128, validation_data=(x_test, x_test))
# Out:
# Epoch 1/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 251s 525ms/step - kl_loss: 4.1756 - reconstruction_loss: 395.7280 - total_loss: 399.9035 - val_kl_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 2/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 254s 541ms/step - kl_loss: 6.0441 - reconstruction_loss: 266.3476 - total_loss: 272.3916 - val_kl_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 3/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 245s 522ms/step - kl_loss: 6.0399 - reconstruction_loss: 262.1013 - total_loss: 268.1412 - val_kl_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 4/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 260s 519ms/step - kl_loss: 6.0984 - reconstruction_loss: 258.9346 - total_loss: 265.0331 - val_kl_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 5/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 270s 536ms/step - kl_loss: 6.1282 - reconstruction_loss: 257.1866 - total_loss: 263.3148 - val_kl_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 6/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 262s 536ms/step - kl_loss: 6.1455 - reconstruction_loss: 257.3871 - total_loss: 263.5325 - val_kl_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 7/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 252s 514ms/step - kl_loss: 6.2132 - reconstruction_loss: 255.8841 - total_loss: 262.0973 - val_kl_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 8/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 245s 523ms/step - kl_loss: 6.2474 - reconstruction_loss: 255.2724 - total_loss: 261.5199 - val_kl_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 9/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 242s 516ms/step - kl_loss: 6.2833 - reconstruction_loss: 254.5113 - total_loss: 260.7947 - val_kl_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 10/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 272s 537ms/step - kl_loss: 6.3062 - reconstruction_loss: 253.7455 - total_loss: 260.0516 - val_kl_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 11/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 238s 508ms/step - kl_loss: 6.3639 - reconstruction_loss: 253.9386 - total_loss: 260.3025 - val_kl_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 12/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 253s 539ms/step - kl_loss: 6.3688 - reconstruction_loss: 253.1534 - total_loss: 259.5223 - val_kl_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 13/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 240s 513ms/step - kl_loss: 6.3874 - reconstruction_loss: 252.7061 - total_loss: 259.0934 - val_kl_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 14/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 255s 498ms/step - kl_loss: 6.4039 - reconstruction_loss: 252.2599 - total_loss: 258.6638 - val_kl_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 15/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 263s 501ms/step - kl_loss: 6.4401 - reconstruction_loss: 251.8286 - total_loss: 258.2688 - val_kl_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 16/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 261s 498ms/step - kl_loss: 6.4568 - reconstruction_loss: 251.9656 - total_loss: 258.4224 - val_kl_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 17/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 233s 496ms/step - kl_loss: 6.4461 - reconstruction_loss: 250.6916 - total_loss: 257.1378 - val_kl_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 18/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 235s 501ms/step - kl_loss: 6.4631 - reconstruction_loss: 251.7014 - total_loss: 258.1645 - val_kl_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 19/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 238s 508ms/step - kl_loss: 6.4779 - reconstruction_loss: 250.8604 - total_loss: 257.3382 - val_kl_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 20/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 243s 519ms/step - kl_loss: 6.5152 - reconstruction_loss: 250.8373 - total_loss: 257.3525 - val_kl_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 21/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 241s 514ms/step - kl_loss: 6.5314 - reconstruction_loss: 250.4660 - total_loss: 256.9974 - val_kl_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 22/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 255s 500ms/step - kl_loss: 6.5267 - reconstruction_loss: 249.9245 - total_loss: 256.4512 - val_kl_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 23/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 234s 499ms/step - kl_loss: 6.5487 - reconstruction_loss: 250.2594 - total_loss: 256.8080 - val_kl_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 24/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 234s 498ms/step - kl_loss: 6.5464 - reconstruction_loss: 250.0153 - total_loss: 256.5617 - val_kl_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 25/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 241s 513ms/step - kl_loss: 6.5783 - reconstruction_loss: 249.5940 - total_loss: 256.1723 - val_kl_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 26/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 232s 494ms/step - kl_loss: 6.5999 - reconstruction_loss: 249.5464 - total_loss: 256.1464 - val_kl_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 27/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 231s 493ms/step - kl_loss: 6.5870 - reconstruction_loss: 249.0709 - total_loss: 255.6579 - val_kl_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 28/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 240s 512ms/step - kl_loss: 6.5781 - reconstruction_loss: 249.8528 - total_loss: 256.4309 - val_kl_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 29/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 233s 497ms/step - kl_loss: 6.6136 - reconstruction_loss: 249.0321 - total_loss: 255.6458 - val_kl_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_total_loss: 0.0000e+00
# Epoch 30/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 241s 514ms/step - kl_loss: 6.6195 - reconstruction_loss: 249.2159 - total_loss: 255.8354 - val_kl_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_total_loss: 0.0000e+00

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# -------------------------------
# 6. Visualisasi Rekonstruksi
# -------------------------------
def plot_reconstructions(model, data, n=10):
    _, _, reconstructions = model(data[:n])
    plt.figure(figsize=(20, 4))
    for i in range(n):
        # Asli
        ax = plt.subplot(2, n, i + 1)
        plt.imshow(data[i].squeeze(), cmap="gray")
        plt.axis("off")
        # Rekonstruksi
        ax = plt.subplot(2, n, i + 1 + n)
        plt.imshow(reconstructions[i].numpy().squeeze(), cmap="gray") # Fixed line
        plt.axis("off")
    plt.show()

plot_reconstructions(vae, x_test)

# -------------------------------
# 7. Simpan Model (opsional)
# -------------------------------
encoder.save("vae_fashion_encoder.h5")
decoder.save("vae_fashion_decoder.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import matplotlib.pyplot as plt

# Asumsi z_means sudah dihitung dan tersedia dari encoder(x_test)
# Jika belum, uncomment baris berikut:
z_means, _, _ = vae.encoder.predict(x_test)

plt.figure(figsize=(10, 8))
plt.scatter(z_means[:, 0], z_means[:, 1], alpha=0.7, s=2)
plt.xlabel("Z-dimension 1")
plt.ylabel("Z-dimension 2")
plt.title("Latent Space Distribution of Fashion-MNIST Test Data")
plt.colorbar(label="Class (if available)") # Label ini akan tetap muncul, namun tidak ada warna berdasarkan kelas karena tidak ada label kelas yang dimuat.
plt.grid(True)
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step

# %%
(_, y_train), (_, y_test) = keras.datasets.fashion_mnist.load_data()
print("y_test successfully loaded with shape:", y_test.shape)
print("First 10 y_test labels:", y_test[:10])
# Out:
# y_test successfully loaded with shape: (10000,)
# First 10 y_test labels: [9 2 1 1 6 1 4 6 5 7]

# %% [markdown]
# ## Generate Latent Space Means for Test Data

# %%
print("Shape of z_means:", z_means.shape)
print("First 5 elements of z_means:\n", z_means[:5])
# Out:
# Shape of z_means: (10000, 2)
# First 5 elements of z_means:
#  [[ 0.10454658  1.2735486 ]
#  [ 0.29626656 -0.14373006]
#  [ 1.4762566  -2.136924  ]
#  [ 0.01740372 -2.1147392 ]
#  [-0.43590662 -0.06241101]]

# %% [markdown]
# ## Visualize Latent Space Distribution by Class

# %%
fashion_mnist_labels = [
    "T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
    "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"
]

plt.figure(figsize=(12, 10))
scatter = plt.scatter(z_means[:, 0], z_means[:, 1], c=y_test, cmap="tab10", alpha=0.7, s=2)
plt.xlabel("Z-dimension 1")
plt.ylabel("Z-dimension 2")
plt.title("Latent Space Distribution of Fashion-MNIST Test Data by Class")
cbar = plt.colorbar(scatter)
cbar.set_label("Class Label")
cbar.set_ticks(range(10))
cbar.set_ticklabels(fashion_mnist_labels)
plt.grid(True)
plt.show()
